# %% [markdown]
# # Assignment using pandas libraries

# %%
# import libraries
import seaborn as sns
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# loading data
pak_data = pd.read_csv('pakistan_dom_prod.csv')
pak_data.head(10)
# Out:
#   Domain Code                             Domain  Area Code      Area  \
# 0          FS  Suite of Food Security Indicators        165  Pakistan
# 1          FS  Suite of Food Security Indicators        165  Pakistan
# 2          FS  Suite of Food Security Indicators        165  Pakistan
# 3          FS  Suite of Food Security Indicators        165  Pakistan
# 4          FS  Suite of Food Security Indicators        165  Pakistan
# 5          FS  Suite of Food Security Indicators        165  Pakistan
# 6          FS  Suite of Food Security Indicators        165  Pakistan
# 7          FS  Suite of Food Security Indicators        165  Pakistan
# 8          FS  Suite of Food Security Indicators        165  Pakistan
# 9          FS  Suite of Food Security Indicators        165  Pakistan
#
#    Element Code Element  Item Code  \
# 0          6126   Value      22013
# 1          6126   Value      22013
# 2          6126   Value      22013
# 3          6126   Value      22013
# ...

# %%
# remonign some columns
new_pak = pak_data.drop(['Area Code', 'Year'], axis=1)
new_pak
# Out:
#    Domain Code                             Domain      Area  Element Code  \
# 0           FS  Suite of Food Security Indicators  Pakistan          6126
# 1           FS  Suite of Food Security Indicators  Pakistan          6126
# 2           FS  Suite of Food Security Indicators  Pakistan          6126
# 3           FS  Suite of Food Security Indicators  Pakistan          6126
# 4           FS  Suite of Food Security Indicators  Pakistan          6126
# 5           FS  Suite of Food Security Indicators  Pakistan          6126
# 6           FS  Suite of Food Security Indicators  Pakistan          6126
# 7           FS  Suite of Food Security Indicators  Pakistan          6126
# 8           FS  Suite of Food Security Indicators  Pakistan          6126
# 9           FS  Suite of Food Security Indicators  Pakistan          6126
# 10          FS  Suite of Food Security Indicators  Pakistan          6126
# 11          FS  Suite of Food Security Indicators  Pakistan          6126
# ...

# %%
# basic statitic or summary
pak_data.describe()
# Out:
#        Area Code  Element Code  Item Code    Year Code         Year  \
# count       21.0          21.0       21.0    21.000000    21.000000
# mean       165.0        6126.0    22013.0  2010.000000  2010.000000
# std          0.0           0.0        0.0     6.204837     6.204837
# min        165.0        6126.0    22013.0  2000.000000  2000.000000
# 25%        165.0        6126.0    22013.0  2005.000000  2005.000000
# 50%        165.0        6126.0    22013.0  2010.000000  2010.000000
# 75%        165.0        6126.0    22013.0  2015.000000  2015.000000
# max        165.0        6126.0    22013.0  2020.000000  2020.000000
#
#              Value  Note
# count    21.000000   0.0
# mean   3973.557143   NaN
# std     465.632400   NaN
# min    3245.400000   NaN
# 25%    3706.800000   NaN
# 50%    3930.500000   NaN
# 75%    4278.300000   NaN
# max    4739.500000   NaN

# %%
# finding mean
pak_data.mean()
# Out:
# C:\Users\DK\AppData\Local\Temp/ipykernel_4868/2323232040.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pak_data.mean()
# Area Code         165.000000
# Element Code     6126.000000
# Item Code       22013.000000
# Year Code        2010.000000
# Year             2010.000000
# Value            3973.557143
# Note                     NaN
# dtype: float64

# %%
pak_data.groupby(['Value']).mean()
# Out:
#         Area Code  Element Code  Item Code  Year Code    Year  Note
# Value
# 3245.4      165.0        6126.0    22013.0     2000.0  2000.0   NaN
# 3277.1      165.0        6126.0    22013.0     2001.0  2001.0   NaN
# 3279.0      165.0        6126.0    22013.0     2002.0  2002.0   NaN
# 3388.2      165.0        6126.0    22013.0     2003.0  2003.0   NaN
# 3560.8      165.0        6126.0    22013.0     2004.0  2004.0   NaN
# 3706.8      165.0        6126.0    22013.0     2005.0  2005.0   NaN
# 3836.5      165.0        6126.0    22013.0     2006.0  2006.0   NaN
# 3906.9      165.0        6126.0    22013.0     2010.0  2010.0   NaN
# 3908.6      165.0        6126.0    22013.0     2008.0  2008.0   NaN
# 3928.5      165.0        6126.0    22013.0     2011.0  2011.0   NaN
# 3930.5      165.0        6126.0    22013.0     2009.0  2009.0   NaN
# 3931.2      165.0        6126.0    22013.0     2007.0  2007.0   NaN
# 3980.7      165.0        6126.0    22013.0     2012.0  2012.0   NaN
# ...

# %%
pak_data.groupby(['Value', 'Year']).mean()
# Out:
#              Area Code  Element Code  Item Code  Year Code  Note
# Value  Year
# 3245.4 2000      165.0        6126.0    22013.0     2000.0   NaN
# 3277.1 2001      165.0        6126.0    22013.0     2001.0   NaN
# 3279.0 2002      165.0        6126.0    22013.0     2002.0   NaN
# 3388.2 2003      165.0        6126.0    22013.0     2003.0   NaN
# 3560.8 2004      165.0        6126.0    22013.0     2004.0   NaN
# 3706.8 2005      165.0        6126.0    22013.0     2005.0   NaN
# 3836.5 2006      165.0        6126.0    22013.0     2006.0   NaN
# 3906.9 2010      165.0        6126.0    22013.0     2010.0   NaN
# 3908.6 2008      165.0        6126.0    22013.0     2008.0   NaN
# 3928.5 2011      165.0        6126.0    22013.0     2011.0   NaN
# 3930.5 2009      165.0        6126.0    22013.0     2009.0   NaN
# 3931.2 2007      165.0        6126.0    22013.0     2007.0   NaN
# 3980.7 2012      165.0        6126.0    22013.0     2012.0   NaN
# ...

# %%
#finding data by specific column value
pak_data[pak_data['Value'] > 3500].mean()
# Out:
# C:\Users\DK\AppData\Local\Temp/ipykernel_4868/4268996653.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pak_data[pak_data['Value'] > 3500].mean()
# Area Code         165.000000
# Element Code     6126.000000
# Item Code       22013.000000
# Year Code        2012.000000
# Year             2012.000000
# Value            4132.647059
# Note                     NaN
# dtype: float64
