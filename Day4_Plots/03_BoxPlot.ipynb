# %% [markdown]
# # 3 - Box Plot

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
phool=sns.load_dataset("iris")
phool
sns.boxplot(x="sepal_length", y="sepal_width", data=phool)  # don't write x= sepal length{no spacing b/w sepal & length}
plt.show()
